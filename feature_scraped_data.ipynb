# %% [markdown]
# # Scraped data Feature Engineering
# This section of code will look into how we can transform the features of the scraped data

# %% [markdown]
# ### Import all necessary libraries

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ### Data Processing
# - Import data into a pandas dataframe
# - Take a look at the data

# %%
# Import the csv file as a pandas dataframe
path = os.getcwd()
scraped_data_path = os.path.join(path, "scraped_data.csv")
df = pd.read_csv(scraped_data_path)
print(df.shape)
# Out:
# (28813, 14)

# %%
df.head(5)
# Out:
#                                    Address               Property Name  \
# 0                   2 Dunman Road (439188)                Grand Dunman
# 1                            Shelford Road               Shelford View
# 2                            Hillview Rise                   Hillhaven
# 3  60H Kent Ridge Hill Residences (117321)  Kent Ridge Hill Residences
# 4                               Marina Way       Marina One Residences
#
#   Property Type Bedrooms Bathrooms             Asking Price        Size  \
# 0     Apartment      4+1         3               $3,764,000  1,679 sqft
# 1   Condominium        5         4              $10,000,000  5,134 sqft
# 2     Apartment        2         2               $1,387,352    678 sqft
# 3     Apartment        1         1  $1,030,000 (Negotiable)    474 sqft
# 4     Apartment        1         1               $1,630,000    700 sqft
#
#           PSF            Age              Tenure No. of Units  \
# 0  $2,242 psf  Not Available  LEASEHOLD/99 years         1008
# 1  $1,948 psf             41            FREEHOLD           20
# 2  $2,046 psf  Not Available  LEASEHOLD/99 years          341
# 3  $2,173 psf              1  LEASEHOLD/99 years          548
# 4  $2,329 psf              7  LEASEHOLD/99 years         1042
#
#                                             District  \
# 0                   D15 - East Coast / Marine Parade
# 1                              D11 - Newton / Novena
# 2   D23 - Dairy Farm / Bukit Panjang / Choa Chu Kang
# 3  D5 - Buona Vista / West Coast / Clementi New Town
# 4            D1 - Boat Quay / Raffles Place / Marina
#
#                                            Amenities  \
# 0  {'Primary Schools': [{'Kong Hwa': '0.41 km'}, ...
# 1  {'Primary Schools': [{"Raffles Girls' Primary"...
# 2  {'Primary Schools': [{'Chij Our Lady Queen Of ...
# 3  {'Primary Schools': [], 'Secondary Schools': [...
# 4  {'Primary Schools': [{'Cantonment Primary': '1...
#
#                                                 Link
# 0  https://www.srx.com.sg/listings/101051671/for-...
# 1  https://www.srx.com.sg/listings/101439641/for-...
# 2  https://www.srx.com.sg/listings/101369031/for-...
# 3  https://www.srx.com.sg/listings/100989811/for-...
# 4  https://www.srx.com.sg/listings/95119111/for-s...

# %% [markdown]
# ### Conducting Feature Selection
# Removing the Property Name and Link Column as it does not provide any useful information

# %%
# The Link column does not look useful as a feature
df.drop(['Link', 'Property Name'], axis=1)
# Out:
#                                        Address  Property Type Bedrooms  \
# 0                       2 Dunman Road (439188)              0      4+1
# 1                                Shelford Road              1        5
# 2                                Hillview Rise              0        2
# 3      60H Kent Ridge Hill Residences (117321)              0        1
# 4                                   Marina Way              0        1
# ...                                        ...            ...      ...
# 28808                            Meyer Mansion              0        3
# 28809                            Jalan Tembusu              1      2+1
# 28810            The Oceanfront @ Sentosa Cove              1        4
# 28811                        Thiam Siew Avenue              0        3
# 28812                               Parc Emily              1        2
#
#        Bathrooms             Asking Price        Size         PSF  Age  \
# 0              3               $3,764,000  1,679 sqft  $2,242 psf    8
# 1              4              $10,000,000  5,134 sqft  $1,948 psf   41
# 2              2               $1,387,352    678 sqft  $2,046 psf    8
# 3              1  $1,030,000 (Negotiable)    474 sqft  $2,173 psf    1
# 4              1               $1,630,000    700 sqft  $2,329 psf    7
# ...          ...                      ...         ...         ...  ...
# 28808          2               $3,580,000  1,109 sqft  $3,228 psf    8
# 28809          2               $2,102,000    883 sqft  $2,381 psf    8
# 28810          5               $7,980,000  3,300 sqft  $2,418 psf   14
# 28811          3               $3,473,000  1,302 sqft  $2,667 psf    8
# 28812          3  $4,180,000 (Negotiable)  1,733 sqft  $2,412 psf   16
#
#                    Tenure  No. of Units  \
# 0      LEASEHOLD/99 years          1008
# 1                FREEHOLD            20
# 2      LEASEHOLD/99 years           341
# 3      LEASEHOLD/99 years           548
# 4      LEASEHOLD/99 years          1042
# ...                   ...           ...
# 28808            FREEHOLD           200
# 28809  LEASEHOLD/99 years           638
# 28810  LEASEHOLD/99 years           264
# 28811            FREEHOLD           816
# 28812            FREEHOLD           295
#
#                                                 District  \
# 0                       D15 - East Coast / Marine Parade
# 1                                  D11 - Newton / Novena
# 2       D23 - Dairy Farm / Bukit Panjang / Choa Chu Kang
# 3      D5 - Buona Vista / West Coast / Clementi New Town
# 4                D1 - Boat Quay / Raffles Place / Marina
# ...                                                  ...
# 28808                   D15 - East Coast / Marine Parade
# 28809                   D15 - East Coast / Marine Parade
# 28810                        D4 - Sentosa / Harbourfront
# 28811                   D15 - East Coast / Marine Parade
# 28812                        D9 - Orchard / River Valley
#
#                                                Amenities
# 0      {'Primary Schools': [{'Kong Hwa': '0.41 km'}, ...
# 1      {'Primary Schools': [{"Raffles Girls' Primary"...
# 2      {'Primary Schools': [{'Chij Our Lady Queen Of ...
# 3      {'Primary Schools': [], 'Secondary Schools': [...
# 4      {'Primary Schools': [{'Cantonment Primary': '1...
# ...                                                  ...
# 28808  {'Primary Schools': [{'Tanjong Katong Primary'...
# 28809  {'Primary Schools': [{'Tanjong Katong Primary'...
# 28810  {'Primary Schools': [], 'Secondary Schools': [...
# 28811  {'Primary Schools': [{'Kong Hwa': '0.7 km'}, {...
# 28812  {'Primary Schools': [{"St. Margaret's Primary"...
#
# [24528 rows x 12 columns]

# %% [markdown]
# ### Data Cleaning
# - We shall encode the Property Types as int
# - We shall perform imputation on the age column
# - We shall drop any rows with NaN values

# %%
df['Property Type'] = df['Property Type'].replace({"Apartment": 0, "Condominium": 1})
df.replace("Not Available", np.nan, inplace=True)
df.head(5)
# Out:
#                                    Address               Property Name  \
# 0                   2 Dunman Road (439188)                Grand Dunman
# 1                            Shelford Road               Shelford View
# 2                            Hillview Rise                   Hillhaven
# 3  60H Kent Ridge Hill Residences (117321)  Kent Ridge Hill Residences
# 4                               Marina Way       Marina One Residences
#
#    Property Type Bedrooms Bathrooms             Asking Price        Size  \
# 0            0.0      4+1         3               $3,764,000  1,679 sqft
# 1            1.0        5         4              $10,000,000  5,134 sqft
# 2            0.0        2         2               $1,387,352    678 sqft
# 3            0.0        1         1  $1,030,000 (Negotiable)    474 sqft
# 4            0.0        1         1               $1,630,000    700 sqft
#
#           PSF  Age              Tenure No. of Units  \
# 0  $2,242 psf  NaN  LEASEHOLD/99 years         1008
# 1  $1,948 psf   41            FREEHOLD           20
# 2  $2,046 psf  NaN  LEASEHOLD/99 years          341
# 3  $2,173 psf    1  LEASEHOLD/99 years          548
# 4  $2,329 psf    7  LEASEHOLD/99 years         1042
#
#                                             District  \
# 0                   D15 - East Coast / Marine Parade
# 1                              D11 - Newton / Novena
# 2   D23 - Dairy Farm / Bukit Panjang / Choa Chu Kang
# 3  D5 - Buona Vista / West Coast / Clementi New Town
# 4            D1 - Boat Quay / Raffles Place / Marina
#
#                                            Amenities  \
# 0  {'Primary Schools': [{'Kong Hwa': '0.41 km'}, ...
# 1  {'Primary Schools': [{"Raffles Girls' Primary"...
# 2  {'Primary Schools': [{'Chij Our Lady Queen Of ...
# 3  {'Primary Schools': [], 'Secondary Schools': [...
# 4  {'Primary Schools': [{'Cantonment Primary': '1...
#
#                                                 Link
# 0  https://www.srx.com.sg/listings/101051671/for-...
# 1  https://www.srx.com.sg/listings/101439641/for-...
# 2  https://www.srx.com.sg/listings/101369031/for-...
# 3  https://www.srx.com.sg/listings/100989811/for-...
# 4  https://www.srx.com.sg/listings/95119111/for-s...

# %%
# Checking nan values
# Check for NaN values in each column
nan_counts_per_column = df.isna().sum()
print("NaN counts per column:")
print(nan_counts_per_column)
# Out:
# NaN counts per column:
# Address             94
# Property Name       94
# Property Type       94
# Bedrooms           195
# Bathrooms          967
# Asking Price       218
# Size                96
# PSF               2967
# Age              11706
# Tenure             239
# No. of Units       826
# District            94
# Amenities            0
# Link                 0
# dtype: int64

# %%
# Handling nan values
# Imputation of NaN age values with the median age
median_age = df['Age'].median()
df['Age'].fillna(median_age, inplace=True)

# Removing all rows with any NaN values
df = df.dropna()
print(df.shape)
# Out:
# (24528, 14)

# %%
df['Bathrooms'] = df['Bathrooms'].astype(int)
df['Age'] = df['Age'].astype(int)
df['No. of Units'] = df['No. of Units'].astype(int)
df['Property Type'] = df['Property Type'].astype(int)
print(df.dtypes)
# Out:
# Address          object
# Property Name    object
# Property Type     int64
# Bedrooms         object
# Bathrooms         int64
# Asking Price     object
# Size             object
# PSF              object
# Age               int64
# Tenure           object
# No. of Units      int64
# District         object
# Amenities        object
# Link             object
# dtype: object
